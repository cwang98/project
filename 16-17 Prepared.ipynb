# %%
import csv

with open( "/Users/ssui9307/Desktop/1617-Reg.txt" , "r") as txt_file:
     with open( "/Users/ssui9307/Desktop/1617-Reg.csv", "w") as csv_file:
                in_txt = csv.reader(txt_file, delimiter = '\t')
                out_csv = csv.writer(csv_file)
                out_csv.writerows(in_txt)

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/Users/ssui9307/Desktop/data1030/Data1030-Final-Project/data/1617_Players_Reg.csv')
#                 names=['Standings','PLAYER', 'TEAM', 'AGE', 'GP', 'W', 'L', 'MIN', 'PTS', 'FGM', 'FGA','FG%','3PM', '3PA', '3P%',
#               'FTM', 'FTA', 'FT%', 'OREB', 'DREB', 'REB', 'AST', 'TOV', 'STL', 'BLK', 'PF', 'FP', 'DD2', 'TD3', '+/-', 'NAN'])

# %%
del df['INDEX']
del df['Unnamed: 0']

# %%
df.head()
# Out:
#               PLAYER TEAM  AGE  GP   W   L   MIN   PTS   FGM   FGA ...    REB  \
# 0  Russell Westbrook  OKC   28  81  46  35  34.6  31.6  10.2  24.0 ...   10.7
# 1       James Harden  HOU   27  81  54  27  36.4  29.1   8.3  18.9 ...    8.1
# 2      Isaiah Thomas  BOS   28  76  51  25  33.8  28.9   9.0  19.4 ...    2.7
# 3      Anthony Davis  NOP   24  75  31  44  36.1  28.0  10.3  20.3 ...   11.8
# 4      DeMar DeRozan  TOR   27  74  47  27  35.4  27.3   9.7  20.9 ...    5.2
#
#     AST  TOV  STL  BLK   PF    FP  DD2  TD3  +/-
# 0  10.4  5.4  1.6  0.4  2.3  60.6   62   42  3.1
# 1  11.2  5.7  1.5  0.5  2.7  55.8   64   22  5.2
# 2   5.9  2.8  0.9  0.2  2.2  41.5    5    0  3.6
# 3   2.1  2.4  1.3  2.2  2.2  53.3   49    0  0.7
# 4   3.9  2.4  1.1  0.2  1.8  40.7    5    0  2.0
#
# [5 rows x 29 columns]

# %%
df.to_csv('1617_Players_Reg.csv')

# %%
with open( "/Users/ssui9307/Desktop/1617-Team-Reg.txt" , "r") as txt_file:
     with open( "/Users/ssui9307/Desktop/1617-Team-Reg.csv", "w") as csv_file:
                in_txt = csv.reader(txt_file, delimiter = '\t')
                out_csv = csv.writer(csv_file)
                out_csv.writerows(in_txt)

# %%
df_team = pd.read_csv('/data/1617-Team-Reg.csv', header=None, 
                     names=['INDEX','TEAM', 'GP', 'W', 'L', 'WIN%', 'MIN', 'PTS', 'FGM', 'FGA','FG%','3PM', '3PA', '3P%',
              'FTM', 'FTA', 'FT%', 'OREB', 'DREB', 'REB', 'AST', 'TOV', 'STL', 'BLK', 'PF', 'FP','PFD', '+/-', 'NAN'])

# %%
del df_team['NAN']
df_team.head()
# Out:
#    INDEX                   TEAM  GP   W   L   WIN%   MIN    PTS   FGM   FGA  \
# 0      1  Golden State Warriors  82  67  15  0.817  48.2  115.9  43.1  87.1
# 1      2      San Antonio Spurs  82  61  21  0.744  48.3  105.3  39.3  83.7
# 2      3        Houston Rockets  82  55  27  0.671  48.2  115.3  40.3  87.2
# 3      4         Boston Celtics  82  53  29  0.646  48.2  108.0  38.6  85.1
# 4      5              Utah Jazz  82  51  31  0.622  48.2  100.7  37.0  79.5
#
#    ...   DREB   REB   AST   TOV  STL  BLK   PF    FP   PFD   +/-
# 0  ...   35.0  44.4  30.4  14.8  9.6  6.8  3.8  19.3  19.4  11.6
# 1  ...   33.9  43.9  23.8  13.4  8.0  5.9  4.1  18.3  19.8   7.2
# 2  ...   33.5  44.4  25.2  15.1  8.2  4.3  5.0  19.9  20.4   5.8
# 3  ...   32.9  42.0  25.2  13.3  7.5  4.1  5.2  20.6  20.3   2.6
# 4  ...   33.8  43.2  20.1  13.6  6.7  5.0  3.8  18.8  20.2   3.9
#
# [5 rows x 28 columns]

# %%
df_team.to_csv('1617_Teams_Reg.csv')

# %%
with open( "/Users/ssui9307/Desktop/1617-Team-Reg-Advanced.txt" , "r") as txt_file:
     with open( "/Users/ssui9307/Desktop/1617-Team-Reg-Advanced.csv", "w") as csv_file:
                in_txt = csv.reader(txt_file, delimiter = '\t')
                out_csv = csv.writer(csv_file)
                out_csv.writerows(in_txt)

# %%
df_team = pd.read_csv('/Users/ssui9307/Desktop/1617-Team-Reg-Advanced.csv', header=None, 
                     names=['TEAM', 'GP', 'W', 'L', 'MIN', 'OFFRTG', 'DEFRTG', 'NETRTG', 'AST%', 'AST/TO',
                            'AST RATIO', 'OREB%', 'DREB%', 'REB%', 'TOV%', 'EFG%', 'TS%', 'PACE', 'PIE', 'NAN'])

# %%
del df_team['NAN']

# %%
df_team.head()
# Out:
#                     TEAM  GP   W   L     MIN  OFFRTG  DEFRTG  NETRTG  AST%  \
# 1  Golden State Warriors  82  67  15  3956.0   113.2   101.1    12.1  70.5
# 2      San Antonio Spurs  82  61  21  3961.0   108.8   100.9     7.9  60.6
# 3        Houston Rockets  82  55  27  3956.0   111.8   106.4     5.4  62.6
# 4         Boston Celtics  82  53  29  3951.0   108.6   105.5     3.1  65.3
# 5              Utah Jazz  82  51  31  3951.0   107.4   102.7     4.7  54.4
#
#    AST/TO  AST RATIO  OREB%  DREB%  REB%  TOV%  EFG%   TS%    PACE   PIE
# 1    2.06       21.4   22.8   74.9  50.5  14.4  56.3  59.7  102.24  57.9
# 2    1.77       18.2   24.0   77.6  51.4  13.9  52.4  56.4   96.41  55.1
# 3    1.67       18.1   24.6   75.8  50.2  14.7  54.5  58.3  102.54  51.6
# 4    1.90       18.9   21.2   75.3  48.5  13.3  52.5  56.7   99.32  51.4
# 5    1.48       16.3   23.2   78.9  51.8  14.5  52.6  56.3   93.62  53.4

# %%
df_team.to_csv('1617_Teams_Reg_Advanced.csv')

# %%
with open( "/Users/ssui9307/Desktop/1617-Team-Reg-FF.txt" , "r") as txt_file:
     with open( "/Users/ssui9307/Desktop/1617-Team-Reg-FF.csv", "w") as csv_file:
                in_txt = csv.reader(txt_file, delimiter = '\t')
                out_csv = csv.writer(csv_file)
                out_csv.writerows(in_txt)

# %%
df_team = pd.read_csv('/Users/ssui9307/Desktop/1617-Team-Reg-FF.csv', header=None, 
                     names=['STANDING','TEAM', 'GP', 'W', 'L', 'WIN%', 'MIN', 'EFG%', 'FTA RATE', 'TOV%', 'OREB%', 'OPP EFG%', 'OPP FTA RATE',
                           'OPP TOV%', 'OPP OREB%', 'NAN'])

del df_team['NAN']

# %%
df_team.head()
# Out:
#    STANDING                   TEAM  GP   W   L   WIN%    MIN  EFG%  FTA RATE  \
# 0         1  Golden State Warriors  82  67  15  0.817  3,956  56.3     0.259
# 1         2      San Antonio Spurs  82  61  21  0.744  3,961  52.4     0.263
# 2         3        Houston Rockets  82  55  27  0.671  3,956  54.5     0.304
# 3         4         Boston Celtics  82  53  29  0.646  3,951  52.5     0.273
# 4         5              Utah Jazz  82  51  31  0.622  3,951  52.6     0.288
#
#    TOV%  OREB%  OPP EFG%  OPP FTA RATE  OPP TOV%  OPP OREB%
# 0  14.4   22.8      48.6         0.261      15.0       25.1
# 1  13.9   24.0      49.2         0.249      14.8       22.4
# 2  14.7   24.6      51.9         0.250      14.6       24.2
# 3  13.3   21.2      50.3         0.290      13.9       24.7
# 4  14.5   23.2      49.3         0.253      12.9       21.1

# %%
df_team.to_csv('data/1617_Teams_Reg_FF.csv', index=False)

# %%
import csv
with open( "/Users/ssui9307/Desktop/1617-AllGames-Reg-Advanced.txt" , "r") as txt_file:
     with open( "/Users/ssui9307/Desktop/1617-AllGames-Reg-Advanced.csv", "w") as csv_file:
                in_txt = csv.reader(txt_file, delimiter = '\t')
                out_csv = csv.writer(csv_file)
                out_csv.writerows(in_txt)

# %%
import pandas as pd
df = pd.read_csv('/Users/ssui9307/Desktop/1617-AllGames-Reg-Advanced.csv', header=None, 
                     names=['TEAM', 'MATCH UP', 'GAME DATE', 'NAN', 'W/L', 'MIN', 'PTS', 'FGM', 'FGA','FG%','3PM', '3PA', '3P%',
              'FTM', 'FTA', 'FT%', 'OREB', 'DREB', 'REB', 'AST', 'TOV', 'STL', 'BLK', 'PF', '+/-', 'NAN1'])

# %%
del df['NAN']
del df['NAN1']

# %%
df.to_csv('data/1617_AllGames_Reg_Advanced.csv')

# %%
df = pd.read_csv('/Users/ssui9307/Desktop/data1030/Data1030-Final-Project/data/1617_Teams_Reg.csv')

# %%
del df['INDEX']
del df['Unnamed: 0']

# %%
df.head()
# Out:
#                     TEAM  GP   W   L   WIN%   MIN    PTS   FGM   FGA   FG%  \
# 0  Golden State Warriors  82  67  15  0.817  48.2  115.9  43.1  87.1  49.5
# 1      San Antonio Spurs  82  61  21  0.744  48.3  105.3  39.3  83.7  46.9
# 2        Houston Rockets  82  55  27  0.671  48.2  115.3  40.3  87.2  46.2
# 3         Boston Celtics  82  53  29  0.646  48.2  108.0  38.6  85.1  45.4
# 4              Utah Jazz  82  51  31  0.622  48.2  100.7  37.0  79.5  46.6
#
#    ...   DREB   REB   AST   TOV  STL  BLK   PF    FP   PFD   +/-
# 0  ...   35.0  44.4  30.4  14.8  9.6  6.8  3.8  19.3  19.4  11.6
# 1  ...   33.9  43.9  23.8  13.4  8.0  5.9  4.1  18.3  19.8   7.2
# 2  ...   33.5  44.4  25.2  15.1  8.2  4.3  5.0  19.9  20.4   5.8
# 3  ...   32.9  42.0  25.2  13.3  7.5  4.1  5.2  20.6  20.3   2.6
# 4  ...   33.8  43.2  20.1  13.6  6.7  5.0  3.8  18.8  20.2   3.9
#
# [5 rows x 27 columns]

# %%
df.to_csv('data/1617_Teams_Reg.csv')

# %%
df = pd.read_csv('/Users/ssui9307/Desktop/data1030/Data1030-Final-Project/data/1617_Teams_Reg_Advanced.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                   TEAM  GP   W   L     MIN  OFFRTG  DEFRTG  \
# 0           1  Golden State Warriors  82  67  15  3956.0   113.2   101.1
# 1           2      San Antonio Spurs  82  61  21  3961.0   108.8   100.9
# 2           3        Houston Rockets  82  55  27  3956.0   111.8   106.4
# 3           4         Boston Celtics  82  53  29  3951.0   108.6   105.5
# 4           5              Utah Jazz  82  51  31  3951.0   107.4   102.7
#
#    NETRTG  AST%  AST/TO  AST RATIO  OREB%  DREB%  REB%  TOV%  EFG%   TS%  \
# 0    12.1  70.5    2.06       21.4   22.8   74.9  50.5  14.4  56.3  59.7
# 1     7.9  60.6    1.77       18.2   24.0   77.6  51.4  13.9  52.4  56.4
# 2     5.4  62.6    1.67       18.1   24.6   75.8  50.2  14.7  54.5  58.3
# 3     3.1  65.3    1.90       18.9   21.2   75.3  48.5  13.3  52.5  56.7
# 4     4.7  54.4    1.48       16.3   23.2   78.9  51.8  14.5  52.6  56.3
#
#      PACE   PIE
# 0  102.24  57.9
# 1   96.41  55.1
# 2  102.54  51.6
# 3   99.32  51.4
# ...

# %%
import csv
import pandas as pd
df = pd.read_csv('data/1617_Players_Reg.csv', index_col=0)

# %%
df.head()
# Out:
#               PLAYER TEAM  AGE  GP   W   L   MIN   PTS   FGM   FGA ...    REB  \
# 0  Russell Westbrook  OKC   28  81  46  35  34.6  31.6  10.2  24.0 ...   10.7
# 1       James Harden  HOU   27  81  54  27  36.4  29.1   8.3  18.9 ...    8.1
# 2      Isaiah Thomas  BOS   28  76  51  25  33.8  28.9   9.0  19.4 ...    2.7
# 3      Anthony Davis  NOP   24  75  31  44  36.1  28.0  10.3  20.3 ...   11.8
# 4      DeMar DeRozan  TOR   27  74  47  27  35.4  27.3   9.7  20.9 ...    5.2
#
#     AST  TOV  STL  BLK   PF    FP  DD2  TD3  +/-
# 0  10.4  5.4  1.6  0.4  2.3  60.6   62   42  3.1
# 1  11.2  5.7  1.5  0.5  2.7  55.8   64   22  5.2
# 2   5.9  2.8  0.9  0.2  2.2  41.5    5    0  3.6
# 3   2.1  2.4  1.3  2.2  2.2  53.3   49    0  0.7
# 4   3.9  2.4  1.1  0.2  1.8  40.7    5    0  2.0
#
# [5 rows x 29 columns]

# %%
grouped = df.groupby('TEAM')

# %%
grouped.head()
# Out:
#                       PLAYER TEAM  AGE  GP   W   L   MIN   PTS   FGM   FGA  \
# 0          Russell Westbrook  OKC   28  81  46  35  34.6  31.6  10.2  24.0
# 1               James Harden  HOU   27  81  54  27  36.4  29.1   8.3  18.9
# 2              Isaiah Thomas  BOS   28  76  51  25  33.8  28.9   9.0  19.4
# 3              Anthony Davis  NOP   24  75  31  44  36.1  28.0  10.3  20.3
# 4              DeMar DeRozan  TOR   27  74  47  27  35.4  27.3   9.7  20.9
# 5             Damian Lillard  POR   26  75  38  37  35.9  27.0   8.8  19.8
# 6           DeMarcus Cousins  NOP   26  72  30  42  34.2  27.0   9.0  19.9
# 7               LeBron James  CLE   32  74  51  23  37.8  26.4   9.9  18.2
# 8              Kawhi Leonard  SAS   26  74  54  20  33.4  25.5   8.6  17.7
# 9              Stephen Curry  GSW   29  79  65  14  33.4  25.3   8.5  18.3
# 10              Kyrie Irving  CLE   25  72  47  25  35.1  25.2   9.3  19.7
# ...

# %%
list_teams = ['ATL','BKN','BOS','CHA','CHI','CLE','DAL','DEN','DET','GSW','HOU','IND','LAC','LAL','MEM','MIA',
              'MIL','MIN','NOP','NYK','OKC','ORL','PHI','PHX','POR','SAC','SAS','TOR','UTA','WAS']

df_allPlayers = pd.DataFrame()    
for i in list_teams:
    df_allPlayers = pd.concat([df_allPlayers, df.loc[df['TEAM'] == i]])

# %%
df_allPlayers.head(30)
# Out:
#                       PLAYER TEAM  AGE  GP   W   L   MIN   PTS  FGM   FGA  \
# 42              Paul Millsap  ATL   32  69  40  29  34.0  18.1  6.2  14.1
# 44           Dennis Schroder  ATL   23  79  42  37  31.5  17.9  6.9  15.4
# 69          Tim Hardaway Jr.  ATL   25  79  42  37  27.3  14.5  5.3  11.5
# 87             Dwight Howard  ATL   31  74  37  37  29.7  13.5  5.2   8.3
# 94            Ersan Ilyasova  ATL   30  82  35  47  26.1  13.1  4.7  10.9
# 119            Kent Bazemore  ATL   27  73  39  34  26.9  11.0  4.0   9.9
# 227          Thabo Sefolosha  ATL   33  62  32  30  25.7   7.2  2.8   6.4
# 272             Mike Muscala  ATL   25  70  36  34  17.7   6.2  2.4   4.8
# 294           Taurean Prince  ATL   23  59  28  31  16.6   5.7  1.9   4.8
# 310          Malcolm Delaney  ATL   28  73  37  36  17.1   5.4  2.0   5.3
# 315            Mike Dunleavy  ATL   36  53  34  19  15.9   5.2  1.8   4.2
# 345           Kris Humphries  ATL   32  56  31  25  12.3   4.6  1.6   3.8
# ...

# %%
len(df_allPlayers)
# Out:
# 486

# %%
df_allPlayers.iloc[1][1]
# Out:
# 'ATL'

# %%
for team in list_teams:
    a=0
    for i in range(len(df_allPlayers)):
        if df_allPlayers.iloc[i][1] == team:
            a+=1
            print(team,a)
# Out:
# ATL 1
# ATL 2
# ATL 3
# ATL 4
# ATL 5
# ATL 6
# ATL 7
# ATL 8
# ATL 9
# ATL 10
# ATL 11
# ATL 12
# ATL 13
# ATL 14
# ATL 15
# ATL 16
# ATL 17
# ATL 18
# BKN 1
# BKN 2
# BKN 3
# BKN 4
# BKN 5
# BKN 6
# BKN 7
# BKN 8
# BKN 9
# BKN 10
# BKN 11
# BKN 12
# BKN 13
# BKN 14
# BKN 15
# BKN 16
# BKN 17
# BKN 18
# BOS 1
# BOS 2
# BOS 3
# BOS 4
# BOS 5
# BOS 6
# BOS 7
# BOS 8
# BOS 9
# BOS 10
# BOS 11
# BOS 12
# BOS 13
# BOS 14
# BOS 15
# CHA 1
# CHA 2
# CHA 3
# CHA 4
# CHA 5
# CHA 6
# CHA 7
# CHA 8
# CHA 9
# CHA 10
# CHA 11
# CHA 12
# CHA 13
# CHA 14
# CHA 15
# CHA 16
# CHA 17
# CHI 1
# CHI 2
# CHI 3
# CHI 4
# CHI 5
# CHI 6
# CHI 7
# CHI 8
# CHI 9
# CHI 10
# CHI 11
# CHI 12
# CHI 13
# CHI 14
# CHI 15
# CHI 16
# CLE 1
# CLE 2
# CLE 3
# CLE 4
# CLE 5
# CLE 6
# CLE 7
# CLE 8
# CLE 9
# CLE 10
# CLE 11
# CLE 12
# CLE 13
# CLE 14
# CLE 15
# CLE 16
# CLE 17
# CLE 18
# CLE 19
# DAL 1
# DAL 2
# DAL 3
# DAL 4
# DAL 5
# DAL 6
# DAL 7
# DAL 8
# DAL 9
# DAL 10
# DAL 11
# DAL 12
# DAL 13
# DAL 14
# DAL 15
# ...

# %%
df_allPlayers.to_csv('data/1617_AllPlayers_byTeam.csv')

# %%
import csv

with open( "/Users/ssui9307/Desktop/1617-AllGames-Reg-Advanced-FF.txt" , "r") as txt_file:
     with open( "/Users/ssui9307/Desktop/1617-AllGames-Reg-Advanced-FF.csv", "w") as csv_file:
                in_txt = csv.reader(txt_file, delimiter = '\t')
                out_csv = csv.writer(csv_file)
                out_csv.writerows(in_txt)

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/Users/ssui9307/Desktop/1617-AllGames-Reg-Advanced-FF.csv',
                 names=['TEAM', 'MATCH UP', 'GAME DATE', 'NAN1','W/L', 'MIN', 'EFG%', 'FTA RATE', 'TOV%', 'OREB%', 'OPP_EFG%',
                        'OPP_FTA RATE', 'OPP_TOV%', 'OPP_OREB%','NAN2'])

# %%
del df['NAN1']
del df['NAN2']

# %%
df.head()
# Out:
#   TEAM     MATCH UP   GAME DATE W/L  MIN   EFG%  FTA RATE  TOV%  OREB%  \
# 0  NYK  NYK vs. PHI  04/12/2017   W   48  54.8%     0.386  19.2  43.6%
# 1  LAL    LAL @ GSW  04/12/2017   L   48  46.2%     0.151  17.0  21.6%
# 2  ATL    ATL @ IND  04/12/2017   L   48  49.3%     0.264  21.7  19.5%
# 3  IND  IND vs. ATL  04/12/2017   W   48  53.7%     0.232  10.8  21.6%
# 4  GSW  GSW vs. LAL  04/12/2017   W   48  52.2%     0.244  19.7  32.6%
#
#   OPP_EFG%  OPP_FTA RATE  OPP_TOV% OPP_OREB%
# 0    53.2%         0.215      13.2     38.1%
# 1    52.2%         0.244      19.7     32.6%
# 2    53.7%         0.232      10.8     21.6%
# 3    49.3%         0.264      21.7     19.5%
# 4    46.2%         0.151      17.0     21.6%

# %%
df.to_csv('data/1617_AllGames_byTeam_FF.csv')

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('data/1617_AllGames_Reg_Advanced.csv', index_col=0)
df_train = pd.read_csv('data/final_train.csv', index_col=0)
df_test = pd.read_csv('data/final_test.csv', index_col=0)

# %%
df.head()
# Out:
#   TEAM     MATCH UP   GAME DATE W/L  MIN  PTS  FGM  FGA   FG%  3PM ...    FT%  \
# 0  HOU  HOU vs. MIN  04/12/2017   W   48  123   45   97  46.4   19 ...   63.6
# 1  ATL    ATL @ IND  04/12/2017   L   48   86   30   72  41.7   11 ...   78.9
# 2  MIL    MIL @ BOS  04/12/2017   L   48   94   37   84  44.0    6 ...   82.4
# 3  OKC  OKC vs. DEN  04/12/2017   L   48  105   43  101  42.6    8 ...   64.7
# 4  LAC  LAC vs. SAC  04/12/2017   W   48  115   43   83  51.8   10 ...   76.0
#
#    OREB  DREB  REB  AST  TOV  STL  BLK  PF  +/-
# 0    16    31   47   37   10   11    7  14    5
# 1     8    29   37   19   20    5    4  15  -18
# 2     9    34   43   26   17    6    9  20  -18
# 3    14    37   51   20   12   10    8  24   -6
# 4    11    32   43   29    6    4    6  15   20
#
# [5 rows x 24 columns]

# %%
del df_train['+/-']
# Out:
#   TEAM GAME DATE  MIN   EFG%  FTA RATE   TOV%  OREB%  OPP_EFG%  OPP_FTA RATE  \
# 0  POR  10/25/16   48  0.607     0.293  0.140  0.167     0.537         0.195
# 1  GSW  10/25/16   48  0.512     0.212  0.159  0.190     0.541         0.265
# 2  CLE  10/25/16   48  0.548     0.202  0.141  0.275     0.420         0.230
# 3  NOP  10/26/16   48  0.429     0.283  0.101  0.096     0.494         0.398
# 4  PHX  10/26/16   48  0.494     0.351  0.186  0.244     0.547         0.302
#
#    OPP_TOV%  OPP_OREB%  OPP  REST  OPP_REST  W/L  +/-
# 0     0.144      0.171  UTA     0         0    1    9
# 1     0.137      0.438  SAS     0         0    0  -29
# 2     0.179      0.245  NYK     0         0    1   29
# 3     0.224      0.282  DEN     0         0    0   -5
# 4     0.138      0.244  SAC     0         0    0  -19
