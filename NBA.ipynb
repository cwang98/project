# %%
import pandas as pd
import numpy as np

# %%
df_players= pd.read_csv('Players Cleaning.csv')

# %%
df_players
# Out:
#          ID  Year                  Player Pos  Age   Tm   G    TS%    FTr  \
# 0     23517  2016              Quincy Acy  PF   25  SAC  59  0.629  0.318
# 1     23518  2016            Jordan Adams  SG   21  MEM   2  0.427  0.833
# 2     23519  2016            Steven Adams   C   22  OKC  80  0.621  0.460
# 3     23520  2016           Arron Afflalo  SG   30  NYK  71  0.531  0.164
# 4     23521  2016           Alexis Ajinca   C   27  NOP  59  0.514  0.197
# 5     23522  2016            Cole Aldrich   C   27  LAC  60  0.626  0.373
# 6     23523  2016       LaMarcus Aldridge  PF   30  SAS  74  0.565  0.289
# 7     23524  2016         Cliff Alexander  PF   20  POR   8  0.500  0.000
# 8     23525  2016             Lavoy Allen  PF   26  IND  79  0.532  0.197
# 9     23526  2016              Tony Allen  SG   34  MEM  64  0.505  0.294
# 10    23527  2016         Al-Farouq Aminu  SF   25  POR  82  0.533  0.217
# 11    23528  2016            Lou Amundson  PF   33  NYK  29  0.401  0.509
# ...
