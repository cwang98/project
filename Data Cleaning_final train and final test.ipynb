# %%
from itertools import product

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFECV
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
df_allTeams = pd.read_csv('data/AllGames_byTeam.csv', encoding = 'latin1',index_col=0)
df_allTeams.head(30)
# Out:
#    TEAM GAME DATE  MIN   EFG%  FTA RATE   TOV%  OREB%  OPP_EFG%  OPP_FTA RATE  \
# 0   ATL  10/27/16   48  0.568     0.205  0.204  0.333     0.457         0.191
# 1   ATL  10/29/16   48  0.524     0.271  0.119  0.146     0.381         0.188
# 2   ATL  10/31/16   48  0.487     0.595  0.136  0.347     0.547         0.253
# 3   ATL   11/2/16   48  0.547     0.341  0.170  0.244     0.583         0.222
# 4   ATL   11/4/16   48  0.416     0.434  0.168  0.222     0.419         0.438
# 5   ATL   11/5/16   48  0.576     0.282  0.195  0.295     0.506         0.153
# 6   ATL   11/8/16   48  0.574     0.296  0.191  0.297     0.429         0.253
# 7   ATL   11/9/16   48  0.560     0.325  0.219  0.361     0.500         0.231
# 8   ATL  11/12/16   48  0.574     0.147  0.157  0.341     0.500         0.241
# 9   ATL  11/15/16   48  0.500     0.238  0.203  0.162     0.444         0.157
# 10  ATL  11/16/16   48  0.556     0.431  0.162  0.086     0.439         0.184
# ...

# %%
# df_home = df_allTeams[df_allTeams['Home/Away'] != 0]
# df_home.head()

# %%
# df_away = df_allTeams[df_allTeams['Home/Away'] != 1]
# df_away.head()
# Out:
#    TEAM GAME DATE  MIN   EFG%  FTA RATE   TOV%  OREB%  OPP_EFG%  OPP_FTA RATE  \
# 1   ATL  10/29/16   48  0.524     0.271  0.119  0.146     0.381         0.188
# 4   ATL   11/4/16   48  0.416     0.434  0.168  0.222     0.419         0.438
# 6   ATL   11/8/16   48  0.574     0.296  0.191  0.297     0.429         0.253
# 9   ATL  11/15/16   48  0.500     0.238  0.203  0.162     0.444         0.157
# 11  ATL  11/18/16   48  0.506     0.202  0.169  0.182     0.467         0.267
#
#     OPP_TOV%  OPP_OREB%  OPP  Home/Away  REST  OPP_REST  W/L
# 1      0.195      0.089  PHI          0     2         3    1
# 4      0.184      0.229  WAS          0     2         2    0
# 6      0.058      0.250  CLE          0     3         3    1
# 9      0.227      0.370  MIA          0     3         1    1
# 11     0.106      0.163  CHA          0     2         3    0

# %%
df_4 = df_allTeams.groupby('TEAM')['EFG%', 'FTA RATE', 'TOV%', 'OREB%'].expanding().mean()

# %%
df_4['TEAM'] = list(df_allTeams['TEAM'].values)

# %%
df_4.head()
# Out:
#             EFG%  FTA RATE     TOV%     OREB% TEAM
# TEAM
# ATL  0  0.568000    0.2050  0.20400  0.333000  ATL
#      1  0.546000    0.2380  0.16150  0.239500  ATL
#      2  0.526333    0.3570  0.15300  0.275333  ATL
#      3  0.531500    0.3530  0.15725  0.267500  ATL
#      4  0.508400    0.3692  0.15940  0.258400  ATL

# %%
efg = list(df_4['EFG%'].values)
fta = list(df_4['FTA RATE'].values)
tov = list(df_4['TOV%'].values)
oreb = list(df_4['OREB%'].values)

df_allTeams['EFG%'] = efg
df_allTeams['FTA RATE'] = fta
df_allTeams['TOV%'] = tov
df_allTeams['OREB%'] = oreb

# %%
df_allTeams.head()
# Out:
#   TEAM GAME DATE  MIN      EFG%  FTA RATE     TOV%     OREB%  OPP_EFG%  \
# 0  ATL  10/27/16   48  0.568000    0.2050  0.20400  0.333000     0.457
# 1  ATL  10/29/16   48  0.546000    0.2380  0.16150  0.239500     0.381
# 2  ATL  10/31/16   48  0.526333    0.3570  0.15300  0.275333     0.547
# 3  ATL   11/2/16   48  0.531500    0.3530  0.15725  0.267500     0.583
# 4  ATL   11/4/16   48  0.508400    0.3692  0.15940  0.258400     0.419
#
#    OPP_FTA RATE  OPP_TOV%  OPP_OREB%  OPP  Home/Away  REST  OPP_REST  W/L
# 0         0.191     0.174      0.240  WAS          1     0         0    1
# 1         0.188     0.195      0.089  PHI          0     2         3    1
# 2         0.253     0.197      0.188  SAC          1     2         2    1
# 3         0.222     0.146      0.289  LAL          1     2         1    0
# 4         0.438     0.184      0.229  WAS          0     2         2    0

# %%
df = pd.read_csv('data/AllGames_byTeam.csv', encoding = 'latin1',index_col=0)
df.head()
# Out:
#   TEAM GAME DATE  MIN   EFG%  FTA RATE   TOV%  OREB%  OPP_EFG%  OPP_FTA RATE  \
# 0  ATL  10/27/16   48  0.568     0.205  0.204  0.333     0.457         0.191
# 1  ATL  10/29/16   48  0.524     0.271  0.119  0.146     0.381         0.188
# 2  ATL  10/31/16   48  0.487     0.595  0.136  0.347     0.547         0.253
# 3  ATL   11/2/16   48  0.547     0.341  0.170  0.244     0.583         0.222
# 4  ATL   11/4/16   48  0.416     0.434  0.168  0.222     0.419         0.438
#
#    OPP_TOV%  OPP_OREB%  OPP  Home/Away  REST  OPP_REST  W/L
# 0     0.174      0.240  WAS          1     0         0    1
# 1     0.195      0.089  PHI          0     2         3    1
# 2     0.197      0.188  SAC          1     2         2    1
# 3     0.146      0.289  LAL          1     2         1    0
# 4     0.184      0.229  WAS          0     2         2    0

# %%
# df_5 = df_away.groupby('TEAM')['EFG%', 'FTA RATE', 'TOV%', 'OREB%'].expanding().mean()
# df_5['TEAM'] = list(df_away['TEAM'].values)
# df_5.head()
# Out:
#              EFG%  FTA RATE      TOV%     OREB% TEAM
# TEAM
# ATL  1   0.524000  0.271000  0.119000  0.146000  ATL
#      4   0.470000  0.352500  0.143500  0.184000  ATL
#      6   0.504667  0.333667  0.159333  0.221667  ATL
#      9   0.503500  0.309750  0.170250  0.206750  ATL
#      11  0.504000  0.288200  0.170000  0.201800  ATL

# %%
# efg = list(df_5['EFG%'].values)
# fta = list(df_5['FTA RATE'].values)
# tov = list(df_5['TOV%'].values)
# oreb = list(df_5['OREB%'].values)

# df_away['EFG%'] = efg
# df_away['FTA RATE'] = fta
# df_away['TOV%'] = tov
# df_away['OREB%'] = oreb
# Out:
# /Users/user/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/user/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /Users/user/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# df_away.head()
# Out:
#    TEAM GAME DATE  MIN      EFG%  FTA RATE      TOV%     OREB%  OPP_EFG%  \
# 1   ATL  10/29/16   48  0.524000  0.271000  0.119000  0.146000     0.381
# 4   ATL   11/4/16   48  0.470000  0.352500  0.143500  0.184000     0.419
# 6   ATL   11/8/16   48  0.504667  0.333667  0.159333  0.221667     0.429
# 9   ATL  11/15/16   48  0.503500  0.309750  0.170250  0.206750     0.444
# 11  ATL  11/18/16   48  0.504000  0.288200  0.170000  0.201800     0.467
#
#     OPP_FTA RATE  OPP_TOV%  OPP_OREB%  OPP  Home/Away  REST  OPP_REST  W/L
# 1          0.188     0.195      0.089  PHI          0     2         3    1
# 4          0.438     0.184      0.229  WAS          0     2         2    0
# 6          0.253     0.058      0.250  CLE          0     3         3    1
# 9          0.157     0.227      0.370  MIA          0     3         1    1
# 11         0.267     0.106      0.163  CHA          0     2         3    0

# %%
# df_home = df_home.reset_index(drop = True)
# del df_home['index']
# df_home.head()
# Out:
#   TEAM GAME DATE  MIN    EFG%  FTA RATE     TOV%    OREB%  OPP_EFG%  \
# 0  ATL  10/27/16   48  0.5680  0.205000  0.20400  0.33300     0.457
# 1  ATL  10/31/16   48  0.5275  0.400000  0.17000  0.34000     0.547
# 2  ATL   11/2/16   48  0.5340  0.380333  0.17000  0.30800     0.583
# 3  ATL   11/5/16   48  0.5445  0.355750  0.17625  0.30475     0.506
# 4  ATL   11/9/16   48  0.5476  0.349600  0.18480  0.31600     0.500
#
#    OPP_FTA RATE  OPP_TOV%  OPP_OREB%  OPP  Home/Away  REST  OPP_REST  W/L
# 0         0.191     0.174      0.240  WAS          1     0         0    1
# 1         0.253     0.197      0.188  SAC          1     2         2    1
# 2         0.222     0.146      0.289  LAL          1     2         1    0
# 3         0.153     0.248      0.279  HOU          1     1         3    1
# 4         0.231     0.132      0.186  CHI          1     1         2    1

# %%
# df_away = df_away.reset_index(drop = True)

# %%
# df_away.head()
# Out:
#   TEAM GAME DATE  MIN      EFG%  FTA RATE      TOV%     OREB%  OPP_EFG%  \
# 0  ATL  10/29/16   48  0.524000  0.271000  0.119000  0.146000     0.381
# 1  ATL   11/4/16   48  0.470000  0.352500  0.143500  0.184000     0.419
# 2  ATL   11/8/16   48  0.504667  0.333667  0.159333  0.221667     0.429
# 3  ATL  11/15/16   48  0.503500  0.309750  0.170250  0.206750     0.444
# 4  ATL  11/18/16   48  0.504000  0.288200  0.170000  0.201800     0.467
#
#    OPP_FTA RATE  OPP_TOV%  OPP_OREB%  OPP  Home/Away  REST  OPP_REST  W/L
# 0         0.188     0.195      0.089  PHI          0     2         3    1
# 1         0.438     0.184      0.229  WAS          0     2         2    0
# 2         0.253     0.058      0.250  CLE          0     3         3    1
# 3         0.157     0.227      0.370  MIA          0     3         1    1
# 4         0.267     0.106      0.163  CHA          0     2         3    0

# %%
list_ = []
for i in range(2460):
    for j in range(2460):
        if df_allTeams['OPP'][i] == df_allTeams['TEAM'][j] and df_allTeams['GAME DATE'][i] == df_allTeams['GAME DATE'][j]:
            list_.append((df_allTeams.iloc[j, 3:7]).tolist())
            break

# %%
len(list_)
# Out:
# 2460

# %%
df_6 = pd.DataFrame(list_)
df_6.columns=['OPP_EFG%','OPP_FTA RATE','OPP_TOV%','OPP_OREB%']
# df = df.transpose()
# df.columns = ['Heading1', 'Heading2']

# %%
df_6.head()
# Out:
#    OPP_EFG%  OPP_FTA RATE  OPP_TOV%  OPP_OREB%
# 0   0.45700       0.19100   0.17400    0.24000
# 1   0.42550       0.24300   0.16500    0.10000
# 2   0.51225       0.34800   0.15825    0.21725
# 3   0.50340       0.25520   0.17140    0.26060
# 4   0.48775       0.31325   0.17725    0.20825

# %%
efg = list(df_6['OPP_EFG%'].values)
fta = list(df_6['OPP_FTA RATE'].values)
tov = list(df_6['OPP_TOV%'].values)
oreb = list(df_6['OPP_OREB%'].values)

df_allTeams['OPP_EFG%'] = efg
df_allTeams['OPP_FTA RATE'] = fta
df_allTeams['OPP_TOV%'] = tov
df_allTeams['OPP_OREB%'] = oreb

# %%
df_allTeams.head()
# Out:
#   TEAM GAME DATE  MIN      EFG%  FTA RATE     TOV%     OREB%  OPP_EFG%  \
# 0  ATL  10/27/16   48  0.568000    0.2050  0.20400  0.333000   0.45700
# 1  ATL  10/29/16   48  0.546000    0.2380  0.16150  0.239500   0.42550
# 2  ATL  10/31/16   48  0.526333    0.3570  0.15300  0.275333   0.51225
# 3  ATL   11/2/16   48  0.531500    0.3530  0.15725  0.267500   0.50340
# 4  ATL   11/4/16   48  0.508400    0.3692  0.15940  0.258400   0.48775
#
#    OPP_FTA RATE  OPP_TOV%  OPP_OREB%  OPP  Home/Away  REST  OPP_REST  W/L
# 0       0.19100   0.17400    0.24000  WAS          1     0         0    1
# 1       0.24300   0.16500    0.10000  PHI          0     2         3    1
# 2       0.34800   0.15825    0.21725  SAC          1     2         2    1
# 3       0.25520   0.17140    0.26060  LAL          1     2         1    0
# 4       0.31325   0.17725    0.20825  WAS          0     2         2    0

# %%
# del df_home['Home/Away']
# df_home.head()
# Out:
#   TEAM GAME DATE  MIN    EFG%  FTA RATE     TOV%    OREB%  OPP_EFG%  \
# 0  ATL  10/27/16   48  0.5680  0.205000  0.20400  0.33300    0.4570
# 1  ATL  10/31/16   48  0.5275  0.400000  0.17000  0.34000    0.5470
# 2  ATL   11/2/16   48  0.5340  0.380333  0.17000  0.30800    0.4860
# 3  ATL   11/5/16   48  0.5445  0.355750  0.17625  0.30475    0.5530
# 4  ATL   11/9/16   48  0.5476  0.349600  0.18480  0.31600    0.5025
#
#    OPP_FTA RATE  OPP_TOV%  OPP_OREB%  OPP  REST  OPP_REST  W/L
# 0       0.19100   0.17400     0.2400  WAS     0         0    1
# 1       0.27750   0.16750     0.2160  SAC     2         2    1
# 2       0.25725   0.17575     0.2570  LAL     2         1    0
# 3       0.29820   0.17140     0.2702  HOU     1         3    1
# 4       0.28300   0.17650     0.2885  CHI     1         2    1

# %%
df_allTeams.to_csv('final_test.csv')

# %%
df_train = pd.read_csv('data/AllGames_byTeam.csv', encoding = 'latin1',index_col=0)
df_train.head()
# Out:
#   TEAM GAME DATE  MIN   EFG%  FTA RATE   TOV%  OREB%  OPP_EFG%  OPP_FTA RATE  \
# 0  ATL  10/27/16   48  0.568     0.205  0.204  0.333     0.457         0.191
# 1  ATL  10/29/16   48  0.524     0.271  0.119  0.146     0.381         0.188
# 2  ATL  10/31/16   48  0.487     0.595  0.136  0.347     0.547         0.253
# 3  ATL   11/2/16   48  0.547     0.341  0.170  0.244     0.583         0.222
# 4  ATL   11/4/16   48  0.416     0.434  0.168  0.222     0.419         0.438
#
#    OPP_TOV%  OPP_OREB%  OPP  Home/Away  REST  OPP_REST  W/L
# 0     0.174      0.240  WAS          1     0         0    1
# 1     0.195      0.089  PHI          0     2         3    1
# 2     0.197      0.188  SAC          1     2         2    1
# 3     0.146      0.289  LAL          1     2         1    0
# 4     0.184      0.229  WAS          0     2         2    0

# %%
df_test=pd.read_csv('final_test.csv',index_col=0)
df_test.head()
# Out:
#   TEAM GAME DATE  MIN   EFG%  FTA RATE   TOV%  OREB%  OPP_EFG%  OPP_FTA RATE  \
# 0  POR  10/25/16   48  0.607     0.293  0.140  0.167     0.537         0.195
# 1  UTA  10/25/16   48  0.537     0.195  0.144  0.171     0.607         0.293
# 2  NYK  10/25/16   48  0.420     0.230  0.179  0.245     0.548         0.202
# 3  GSW  10/25/16   48  0.512     0.212  0.159  0.190     0.541         0.265
# 4  SAS  10/25/16   48  0.541     0.265  0.137  0.438     0.512         0.212
#
#    OPP_TOV%  OPP_OREB%  OPP  Home/Away  REST  OPP_REST  W/L  +/-
# 0     0.144      0.171  UTA          1     0         0    1    9
# 1     0.140      0.167  POR          0     0         0    0   -9
# 2     0.141      0.275  CLE          0     0         0    0  -29
# 3     0.137      0.438  SAS          1     0         0    0  -29
# 4     0.159      0.190  GSW          0     0         0    1   29

# %%
# df_train = df_train[df_train['Home/Away'] != 0]
# df_train.head()
# Out:
#   TEAM GAME DATE  MIN   EFG%  FTA RATE   TOV%  OREB%  OPP_EFG%  OPP_FTA RATE  \
# 0  ATL  10/27/16   48  0.568     0.205  0.204  0.333     0.457         0.191
# 2  ATL  10/31/16   48  0.487     0.595  0.136  0.347     0.547         0.253
# 3  ATL   11/2/16   48  0.547     0.341  0.170  0.244     0.583         0.222
# 5  ATL   11/5/16   48  0.576     0.282  0.195  0.295     0.506         0.153
# 7  ATL   11/9/16   48  0.560     0.325  0.219  0.361     0.500         0.231
#
#    OPP_TOV%  OPP_OREB%  OPP  Home/Away  REST  OPP_REST  W/L
# 0     0.174      0.240  WAS          1     0         0    1
# 2     0.197      0.188  SAC          1     2         2    1
# 3     0.146      0.289  LAL          1     2         1    0
# 5     0.248      0.279  HOU          1     1         3    1
# 7     0.132      0.186  CHI          1     1         2    1

# %%
# df_train = df_train.reset_index(drop = True)
# df_train.head()
# Out:
#   TEAM GAME DATE  MIN   EFG%  FTA RATE   TOV%  OREB%  OPP_EFG%  OPP_FTA RATE  \
# 0  ATL  10/27/16   48  0.568     0.205  0.204  0.333     0.457         0.191
# 1  ATL  10/31/16   48  0.487     0.595  0.136  0.347     0.547         0.253
# 2  ATL   11/2/16   48  0.547     0.341  0.170  0.244     0.583         0.222
# 3  ATL   11/5/16   48  0.576     0.282  0.195  0.295     0.506         0.153
# 4  ATL   11/9/16   48  0.560     0.325  0.219  0.361     0.500         0.231
#
#    OPP_TOV%  OPP_OREB%  OPP  Home/Away  REST  OPP_REST  W/L
# 0     0.174      0.240  WAS          1     0         0    1
# 1     0.197      0.188  SAC          1     2         2    1
# 2     0.146      0.289  LAL          1     2         1    0
# 3     0.248      0.279  HOU          1     1         3    1
# 4     0.132      0.186  CHI          1     1         2    1

# %%
# del df_train['Home/Away']
# df_train.head()
# Out:
#   TEAM GAME DATE  MIN   EFG%  FTA RATE   TOV%  OREB%  OPP_EFG%  OPP_FTA RATE  \
# 0  ATL  10/27/16   48  0.568     0.205  0.204  0.333     0.457         0.191
# 1  ATL  10/31/16   48  0.487     0.595  0.136  0.347     0.547         0.253
# 2  ATL   11/2/16   48  0.547     0.341  0.170  0.244     0.583         0.222
# 3  ATL   11/5/16   48  0.576     0.282  0.195  0.295     0.506         0.153
# 4  ATL   11/9/16   48  0.560     0.325  0.219  0.361     0.500         0.231
#
#    OPP_TOV%  OPP_OREB%  OPP  REST  OPP_REST  W/L
# 0     0.174      0.240  WAS     0         0    1
# 1     0.197      0.188  SAC     2         2    1
# 2     0.146      0.289  LAL     2         1    0
# 3     0.248      0.279  HOU     1         3    1
# 4     0.132      0.186  CHI     1         2    1

# %%
df_train.to_csv('final_train.csv')

# %%
df = pd.read_csv('data/1617_AllGames_byTeam.csv', encoding = 'latin1',index_col=0)
df.head()
# Out:
#   TEAM  OPP  Home/Away   GAME DATE  REST  OPP_REST  MIN  PTS  FGM  FGA ...   \
# 0  ATL  WAS          1  10/27/2016     0         0   48  114   44   88 ...
# 1  ATL  PHI          0  10/29/2016     2         3   48  104   42   85 ...
# 2  ATL  SAC          1  10/31/2016     2         2   48  106   33   79 ...
# 3  ATL  LAL          1  11/02/2016     2         1   48  116   41   85 ...
# 4  ATL  WAS          0  11/04/2016     2         2   48   92   32   83 ...
#
#    OPP_OREB  OPP_DREB  OPP_REB  OPP_AST  OPP_TOV  OPP_STL  OPP_BLK  OPP_PF  \
# 0        12        28       40       25       19       14        4      20
# 1         4        35       39       16       20        9        5      20
# 2         6        32       38       26       19       10        6      34
# 3        11        31       42       24       15       11        9      25
# 4        11        35       46       13       19        7        3      23
#
#    SAME TYPE  WIN
# 0          1    1
# 1          1    1
# ...

# %%
# df = df[df['Home/Away'] != 0]
# df.head()
# Out:
#   TEAM  OPP  Home/Away   GAME DATE  REST  OPP_REST  MIN  PTS  FGM  FGA ...   \
# 0  ATL  WAS          1  10/27/2016     0         0   48  114   44   88 ...
# 2  ATL  SAC          1  10/31/2016     2         2   48  106   33   79 ...
# 3  ATL  LAL          1  11/02/2016     2         1   48  116   41   85 ...
# 5  ATL  HOU          1  11/05/2016     1         3   48  112   45   85 ...
# 7  ATL  CHI          1  11/09/2016     1         2   48  115   42   83 ...
#
#    OPP_OREB  OPP_DREB  OPP_REB  OPP_AST  OPP_TOV  OPP_STL  OPP_BLK  OPP_PF  \
# 0        12        28       40       25       19       14        4      20
# 2         6        32       38       26       19       10        6      34
# 3        11        31       42       24       15       11        9      25
# 5        12        31       43       22       26        9        7      26
# 7         8        23       31       24       14       14        3      21
#
#    SAME TYPE  WIN
# 0          1    1
# 2          1    1
# ...

# %%
# df = df.reset_index(drop = True)
# df.head()
# Out:
#   TEAM  OPP  Home/Away   GAME DATE  REST  OPP_REST  MIN  PTS  FGM  FGA ...   \
# 0  ATL  WAS          1  10/27/2016     0         0   48  114   44   88 ...
# 1  ATL  SAC          1  10/31/2016     2         2   48  106   33   79 ...
# 2  ATL  LAL          1  11/02/2016     2         1   48  116   41   85 ...
# 3  ATL  HOU          1  11/05/2016     1         3   48  112   45   85 ...
# 4  ATL  CHI          1  11/09/2016     1         2   48  115   42   83 ...
#
#    OPP_OREB  OPP_DREB  OPP_REB  OPP_AST  OPP_TOV  OPP_STL  OPP_BLK  OPP_PF  \
# 0        12        28       40       25       19       14        4      20
# 1         6        32       38       26       19       10        6      34
# 2        11        31       42       24       15       11        9      25
# 3        12        31       43       22       26        9        7      26
# 4         8        23       31       24       14       14        3      21
#
#    SAME TYPE  WIN
# 0          1    1
# 1          1    1
# ...

# %%
# list_pm=[]
# for i in range(2460):
#     #print(i)
#     for j in range(2460):
#         if df['TEAM'][j] == df_train['TEAM'][i] and df['GAME DATE'][j] == df_train['GAME DATE'][i]:
#             print(j)
#             list_pm.append(df.iloc[j]['+/-'])
#             break

# %%
del df_train['+/-']

# %%
# df_pm = pd.DataFrame(list_pm, columns = ['+/-'])
# df_train = pd.concat([df_train, df_pm], axis=1)
# df_train.head()
# Out:
#   TEAM GAME DATE  MIN   EFG%  FTA RATE   TOV%  OREB%  OPP_EFG%  OPP_FTA RATE  \
# 0  ATL  10/27/16   48  0.568     0.205  0.204  0.333     0.457         0.191
# 1  ATL  10/29/16   48  0.524     0.271  0.119  0.146     0.381         0.188
# 2  ATL  10/31/16   48  0.487     0.595  0.136  0.347     0.547         0.253
# 3  ATL   11/2/16   48  0.547     0.341  0.170  0.244     0.583         0.222
# 4  ATL   11/4/16   48  0.416     0.434  0.168  0.222     0.419         0.438
#
#    OPP_TOV%  OPP_OREB%  OPP  Home/Away  REST  OPP_REST  W/L  +/-
# 0     0.174      0.240  WAS          1     0         0    1  NaN
# 1     0.195      0.089  PHI          0     2         3    1  NaN
# 2     0.197      0.188  SAC          1     2         2    1  NaN
# 3     0.146      0.289  LAL          1     2         1    0  NaN
# 4     0.184      0.229  WAS          0     2         2    0  NaN

# %%
df_train['+/-']=df['+/-']
df_train.head()
# Out:
#   TEAM GAME DATE  MIN   EFG%  FTA RATE   TOV%  OREB%  OPP_EFG%  OPP_FTA RATE  \
# 0  ATL  10/27/16   48  0.568     0.205  0.204  0.333     0.457         0.191
# 1  ATL  10/29/16   48  0.524     0.271  0.119  0.146     0.381         0.188
# 2  ATL  10/31/16   48  0.487     0.595  0.136  0.347     0.547         0.253
# 3  ATL   11/2/16   48  0.547     0.341  0.170  0.244     0.583         0.222
# 4  ATL   11/4/16   48  0.416     0.434  0.168  0.222     0.419         0.438
#
#    OPP_TOV%  OPP_OREB%  OPP  Home/Away  REST  OPP_REST  W/L  +/-
# 0     0.174      0.240  WAS          1     0         0    1   15
# 1     0.195      0.089  PHI          0     2         3    1   32
# 2     0.197      0.188  SAC          1     2         2    1   11
# 3     0.146      0.289  LAL          1     2         1    0   -7
# 4     0.184      0.229  WAS          0     2         2    0   -3

# %%
df_train.to_csv('final_train.csv')

# %%
df_allTeams['+/-']=df['+/-']
df_allTeams.head()
# Out:
#   TEAM GAME DATE  MIN      EFG%  FTA RATE     TOV%     OREB%  OPP_EFG%  \
# 0  ATL  10/27/16   48  0.568000    0.2050  0.20400  0.333000   0.45700
# 1  ATL  10/29/16   48  0.546000    0.2380  0.16150  0.239500   0.42550
# 2  ATL  10/31/16   48  0.526333    0.3570  0.15300  0.275333   0.51225
# 3  ATL   11/2/16   48  0.531500    0.3530  0.15725  0.267500   0.50340
# 4  ATL   11/4/16   48  0.508400    0.3692  0.15940  0.258400   0.48775
#
#    OPP_FTA RATE  OPP_TOV%  OPP_OREB%  OPP  Home/Away  REST  OPP_REST  W/L  +/-
# 0       0.19100   0.17400    0.24000  WAS          1     0         0    1   15
# 1       0.24300   0.16500    0.10000  PHI          0     2         3    1   32
# 2       0.34800   0.15825    0.21725  SAC          1     2         2    1   11
# 3       0.25520   0.17140    0.26060  LAL          1     2         1    0   -7
# 4       0.31325   0.17725    0.20825  WAS          0     2         2    0   -3

# %%
df_allTeams.to_csv('final_test.csv')

# %%
df_order = pd.read_csv('1617_AllGames_byTeam_FF.csv', encoding = 'latin1',index_col=0)
df_order.head()
# Out:
#   TEAM     MATCH UP GAME DATE  MIN   EFG%  FTA RATE   TOV%   TOV  OREB%  \
# 0  POR  POR vs. UTA  10/25/16   48  0.607     0.293  0.140  14.0  0.167
# 1  UTA    UTA @ POR  10/25/16   48  0.537     0.195  0.144  14.4  0.171
# 2  NYK    NYK @ CLE  10/25/16   48  0.420     0.230  0.179  17.9  0.245
# 3  GSW  GSW vs. SAS  10/25/16   48  0.512     0.212  0.159  15.9  0.190
# 4  SAS    SAS @ GSW  10/25/16   48  0.541     0.265  0.137  13.7  0.438
#
#    OPP_EFG%    ...     OPP_TOV  OPP_OREB%  OPP  Home/Away REST  PTS  OPP_PTS  \
# 0     0.537    ...        14.4      0.171  UTA          1    0  113      104
# 1     0.607    ...        14.0      0.167  POR          0    0  104      113
# 2     0.548    ...        14.1      0.275  CLE          0    0   88      117
# 3     0.541    ...        13.7      0.438  SAS          1    0  100      129
# 4     0.512    ...        15.9      0.190  GSW          0    0  129      100
#
#    +/-  WIN  OPP_REST
# 0    9    1         0
# 1   -9    0         0
# ...

# %%
df_train.head()
# Out:
#   TEAM GAME DATE  MIN   EFG%  FTA RATE   TOV%  OREB%  OPP_EFG%  OPP_FTA RATE  \
# 0  ATL  10/27/16   48  0.568     0.205  0.204  0.333     0.457         0.191
# 1  ATL  10/31/16   48  0.487     0.595  0.136  0.347     0.547         0.253
# 2  ATL   11/2/16   48  0.547     0.341  0.170  0.244     0.583         0.222
# 3  ATL   11/5/16   48  0.576     0.282  0.195  0.295     0.506         0.153
# 4  ATL   11/9/16   48  0.560     0.325  0.219  0.361     0.500         0.231
#
#    OPP_TOV%  OPP_OREB%  OPP  REST  OPP_REST  W/L  +/-
# 0     0.174      0.240  WAS     0         0    1   15
# 1     0.197      0.188  SAC     2         2    1   11
# 2     0.146      0.289  LAL     2         1    0   -7
# 3     0.248      0.279  HOU     1         3    1   15
# 4     0.132      0.186  CHI     1         2    1    8

# %%
### reorder train
df_reorder = pd.DataFrame()
for i in range(2460):
    for j in range(2460):
        if df_train.loc[j,'TEAM']==df_order.loc[i,'TEAM'] and df_train.loc[j,'GAME DATE']==df_order.loc[i,'GAME DATE']:
            print(df_train.iloc[j,:])
            df_reorder = pd.concat([df_reorder, df_train.loc[j,:]], axis=1)
            break
# Out:
# TEAM                 POR
# GAME DATE       10/25/16
# MIN                   48
# EFG%               0.607
# FTA RATE           0.293
# TOV%                0.14
# OREB%              0.167
# OPP_EFG%           0.537
# OPP_FTA RATE       0.195
# OPP_TOV%           0.144
# OPP_OREB%          0.171
# OPP                  UTA
# Home/Away              1
# REST                   0
# OPP_REST               0
# W/L                    1
# +/-                    9
# Name: 1968, dtype: object
# TEAM                 UTA
# GAME DATE       10/25/16
# MIN                   48
# EFG%               0.537
# FTA RATE           0.195
# TOV%               0.144
# OREB%              0.171
# OPP_EFG%           0.607
# OPP_FTA RATE       0.293
# OPP_TOV%            0.14
# OPP_OREB%          0.167
# OPP                  POR
# Home/Away              0
# REST                   0
# OPP_REST               0
# W/L                    0
# +/-                   -9
# Name: 2296, dtype: object
# ...

# %%
df_reorder = df_reorder.T
df_reorder.head()
# Out:
#       +/-   EFG% FTA RATE GAME DATE Home/Away MIN  OPP OPP_EFG% OPP_FTA RATE  \
# 1968    9  0.607    0.293  10/25/16         1  48  UTA    0.537        0.195
# 2296   -9  0.537    0.195  10/25/16         0  48  POR    0.607        0.293
# 1558  -29   0.42     0.23  10/25/16         0  48  CLE    0.548        0.202
# 738   -29  0.512    0.212  10/25/16         1  48  SAS    0.541        0.265
# 2132   29  0.541    0.265  10/25/16         0  48  GSW    0.512        0.212
#
#      OPP_OREB% OPP_REST OPP_TOV%  OREB% REST TEAM   TOV% W/L
# 1968     0.171        0    0.144  0.167    0  POR   0.14   1
# 2296     0.167        0     0.14  0.171    0  UTA  0.144   0
# 1558     0.275        0    0.141  0.245    0  NYK  0.179   0
# 738      0.438        0    0.137   0.19    0  GSW  0.159   0
# 2132      0.19        0    0.159  0.438    0  SAS  0.137   1

# %%
df_train.head()
# Out:
#   TEAM GAME DATE  MIN   EFG%  FTA RATE   TOV%  OREB%  OPP_EFG%  OPP_FTA RATE  \
# 0  ATL  10/27/16   48  0.568     0.205  0.204  0.333     0.457         0.191
# 1  ATL  10/29/16   48  0.524     0.271  0.119  0.146     0.381         0.188
# 2  ATL  10/31/16   48  0.487     0.595  0.136  0.347     0.547         0.253
# 3  ATL   11/2/16   48  0.547     0.341  0.170  0.244     0.583         0.222
# 4  ATL   11/4/16   48  0.416     0.434  0.168  0.222     0.419         0.438
#
#    OPP_TOV%  OPP_OREB%  OPP  Home/Away  REST  OPP_REST  W/L  +/-
# 0     0.174      0.240  WAS          1     0         0    1   15
# 1     0.195      0.089  PHI          0     2         3    1   32
# 2     0.197      0.188  SAC          1     2         2    1   11
# 3     0.146      0.289  LAL          1     2         1    0   -7
# 4     0.184      0.229  WAS          0     2         2    0   -3

# %%
df_reorder=df_reorder[['TEAM','GAME DATE','MIN','EFG%','FTA RATE','TOV%','OREB%','OPP_EFG%','OPP_FTA RATE','OPP_TOV%','OPP_OREB%','OPP','Home/Away','REST','OPP_REST','W/L','+/-']]
df_reorder.head()
# Out:
#      TEAM GAME DATE MIN   EFG% FTA RATE   TOV%  OREB% OPP_EFG% OPP_FTA RATE  \
# 1968  POR  10/25/16  48  0.607    0.293   0.14  0.167    0.537        0.195
# 2296  UTA  10/25/16  48  0.537    0.195  0.144  0.171    0.607        0.293
# 1558  NYK  10/25/16  48   0.42     0.23  0.179  0.245    0.548        0.202
# 738   GSW  10/25/16  48  0.512    0.212  0.159   0.19    0.541        0.265
# 2132  SAS  10/25/16  48  0.541    0.265  0.137  0.438    0.512        0.212
#
#      OPP_TOV% OPP_OREB%  OPP Home/Away REST OPP_REST W/L  +/-
# 1968    0.144     0.171  UTA         1    0        0   1    9
# 2296     0.14     0.167  POR         0    0        0   0   -9
# 1558    0.141     0.275  CLE         0    0        0   0  -29
# 738     0.137     0.438  SAS         1    0        0   0  -29
# 2132    0.159      0.19  GSW         0    0        0   1   29

# %%
df_reorder = df_reorder.reset_index(drop = True)
df_reorder.head()
# Out:
#   TEAM GAME DATE MIN   EFG% FTA RATE   TOV%  OREB% OPP_EFG% OPP_FTA RATE  \
# 0  POR  10/25/16  48  0.607    0.293   0.14  0.167    0.537        0.195
# 1  UTA  10/25/16  48  0.537    0.195  0.144  0.171    0.607        0.293
# 2  NYK  10/25/16  48   0.42     0.23  0.179  0.245    0.548        0.202
# 3  GSW  10/25/16  48  0.512    0.212  0.159   0.19    0.541        0.265
# 4  SAS  10/25/16  48  0.541    0.265  0.137  0.438    0.512        0.212
#
#   OPP_TOV% OPP_OREB%  OPP Home/Away REST OPP_REST W/L  +/-
# 0    0.144     0.171  UTA         1    0        0   1    9
# 1     0.14     0.167  POR         0    0        0   0   -9
# 2    0.141     0.275  CLE         0    0        0   0  -29
# 3    0.137     0.438  SAS         1    0        0   0  -29
# 4    0.159      0.19  GSW         0    0        0   1   29

# %%
len(df_reorder)
# Out:
# 2460

# %%
df_reorder.to_csv('final_train.csv')

# %%
## reorder test
df_reorder = pd.DataFrame()
for i in range(2460):
    for j in range(2460):
        if df_allTeams.loc[j,'TEAM']==df_order.loc[i,'TEAM'] and df_allTeams.loc[j,'GAME DATE']==df_order.loc[i,'GAME DATE']:
            print(df_allTeams.iloc[j,:])
            df_reorder = pd.concat([df_reorder, df_allTeams.loc[j,:]], axis=1)
            break
# Out:
# TEAM                 POR
# GAME DATE       10/25/16
# MIN                   48
# EFG%               0.607
# FTA RATE           0.293
# TOV%                0.14
# OREB%              0.167
# OPP_EFG%           0.537
# OPP_FTA RATE       0.195
# OPP_TOV%           0.144
# OPP_OREB%          0.171
# OPP                  UTA
# Home/Away              1
# REST                   0
# OPP_REST               0
# W/L                    1
# +/-                    9
# Name: 1968, dtype: object
# TEAM                 UTA
# GAME DATE       10/25/16
# MIN                   48
# EFG%               0.537
# FTA RATE           0.195
# TOV%               0.144
# OREB%              0.171
# OPP_EFG%           0.607
# OPP_FTA RATE       0.293
# OPP_TOV%            0.14
# OPP_OREB%          0.167
# OPP                  POR
# Home/Away              0
# REST                   0
# OPP_REST               0
# W/L                    0
# +/-                   -9
# Name: 2296, dtype: object
# ...

# %%
df_reorder = df_reorder.T
df_reorder.head()
# Out:
#       +/-   EFG% FTA RATE GAME DATE Home/Away MIN  OPP OPP_EFG% OPP_FTA RATE  \
# 1968    9  0.607    0.293  10/25/16         1  48  UTA    0.537        0.195
# 2296   -9  0.537    0.195  10/25/16         0  48  POR    0.607        0.293
# 1558  -29   0.42     0.23  10/25/16         0  48  CLE    0.548        0.202
# 738   -29  0.512    0.212  10/25/16         1  48  SAS    0.541        0.265
# 2132   29  0.541    0.265  10/25/16         0  48  GSW    0.512        0.212
#
#      OPP_OREB% OPP_REST OPP_TOV%  OREB% REST TEAM   TOV% W/L
# 1968     0.171        0    0.144  0.167    0  POR   0.14   1
# 2296     0.167        0     0.14  0.171    0  UTA  0.144   0
# 1558     0.275        0    0.141  0.245    0  NYK  0.179   0
# 738      0.438        0    0.137   0.19    0  GSW  0.159   0
# 2132      0.19        0    0.159  0.438    0  SAS  0.137   1

# %%
df_reorder=df_reorder[['TEAM','GAME DATE','MIN','EFG%','FTA RATE','TOV%','OREB%','OPP_EFG%','OPP_FTA RATE','OPP_TOV%','OPP_OREB%','OPP','Home/Away','REST','OPP_REST','W/L','+/-']]
df_reorder.head()
# Out:
#      TEAM GAME DATE MIN   EFG% FTA RATE   TOV%  OREB% OPP_EFG% OPP_FTA RATE  \
# 1968  POR  10/25/16  48  0.607    0.293   0.14  0.167    0.537        0.195
# 2296  UTA  10/25/16  48  0.537    0.195  0.144  0.171    0.607        0.293
# 1558  NYK  10/25/16  48   0.42     0.23  0.179  0.245    0.548        0.202
# 738   GSW  10/25/16  48  0.512    0.212  0.159   0.19    0.541        0.265
# 2132  SAS  10/25/16  48  0.541    0.265  0.137  0.438    0.512        0.212
#
#      OPP_TOV% OPP_OREB%  OPP Home/Away REST OPP_REST W/L  +/-
# 1968    0.144     0.171  UTA         1    0        0   1    9
# 2296     0.14     0.167  POR         0    0        0   0   -9
# 1558    0.141     0.275  CLE         0    0        0   0  -29
# 738     0.137     0.438  SAS         1    0        0   0  -29
# 2132    0.159      0.19  GSW         0    0        0   1   29

# %%
df_reorder = df_reorder.reset_index(drop = True)
df_reorder.head()
# Out:
#   TEAM GAME DATE MIN   EFG% FTA RATE   TOV%  OREB% OPP_EFG% OPP_FTA RATE  \
# 0  POR  10/25/16  48  0.607    0.293   0.14  0.167    0.537        0.195
# 1  UTA  10/25/16  48  0.537    0.195  0.144  0.171    0.607        0.293
# 2  NYK  10/25/16  48   0.42     0.23  0.179  0.245    0.548        0.202
# 3  GSW  10/25/16  48  0.512    0.212  0.159   0.19    0.541        0.265
# 4  SAS  10/25/16  48  0.541    0.265  0.137  0.438    0.512        0.212
#
#   OPP_TOV% OPP_OREB%  OPP Home/Away REST OPP_REST W/L  +/-
# 0    0.144     0.171  UTA         1    0        0   1    9
# 1     0.14     0.167  POR         0    0        0   0   -9
# 2    0.141     0.275  CLE         0    0        0   0  -29
# 3    0.137     0.438  SAS         1    0        0   0  -29
# 4    0.159      0.19  GSW         0    0        0   1   29

# %%
df_reorder.to_csv('final_test.csv')
